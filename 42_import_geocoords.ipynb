# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/geo_collect.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                                  0  \
# 0           0  2449, 23rd Street, Potrero Terrace, SF, Califo...
# 1           1                                                NaN
# 2           2  416, Bay Street, Russian Hill, SF, California,...
# 3           3  AT&T Park, 24, Willie Mays Plaza, South Beach,...
# 4           4  Cathay Express Restaurant, 720, 14th Street, D...
#
#                                                    1  \
# 0                                                NaN
# 1  1101, Grant Avenue, Chinatown, SF, California,...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                    2  \
# 0  909, Grant Avenue, Chinatown, SF, California, ...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
df['0'][2]
# Out:
# '416, Bay Street, Russian Hill, SF, California, 94133, United States of America'

# %% [markdown]
# ## list of geo coords

# %%
geo_lst_np = np.array(df)

# %%
geo_lst = []
for geo in geo_lst_np:
    for i in geo:
        geo_lst.append(i)

# %%
len(geo_lst)
# Out:
# 2346
