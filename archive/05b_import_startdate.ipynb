# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.style.use('seaborn-notebook')
# %matplotlib inline

# %%
df = pd.read_csv('../data/data_zipcode_imported.csv')

# %%
# SF business locations file
df_b = pd.read_csv('../data/Registered_Business_Locations_-_San_Francisco.csv')

# %%
df_b_3cols = df_b[['Street Address', 'Source Zipcode', 'Business Start Date']]

# %%
# let's identify '1051 Market St' business transactions in SF business loc
df_b_3cols[df_b_3cols['Street Address'] == '1051 Market St']
# Out:
#         Street Address  Source Zipcode Business Start Date
# 65775   1051 Market St         94103.0          02/01/2008
# 135617  1051 Market St         94103.0          12/17/2014
# 214983  1051 Market St         94103.0          09/01/2013

# %%
# Let's get all the addresses
address_lst = df['business_address'].tolist()

# %%
len(address_lst)
# Out:
# 5229

# %%
address_unique_lst = list(set(address_lst))

# %%
len(address_unique_lst)
# Out:
# 4829

# %%
df_otg = df[df['business_address'] == 'Off The Grid']

# %%
len(df_otg)
# Out:
# 41

# %%
# No address or unreal addresses will be assigned with the average startdate.

# %%
for address in address_unique_lst:
    df_b_3unique = df_b_3cols[df_b_3cols['Street Address'] == address]
    if len(df_b_3unique) > 0:
        num_turnovers = len(df_b_3unique)
        latest_startdate = pd.to_datetime(max(df_b_3unique['Business Start Date'].values))
        # let's append these info onto df
        idx = df[df['business_address'] == address].index
        df.loc[idx,'number_turnovers'] = num_turnovers
        df.loc[idx,'start_date'] = latest_startdate

# %%
df_test = df_b_3cols[df_b_3cols['Street Address'] == '1051 Market St']

# %%
df_test
# Out:
#         Street Address  Source Zipcode Business Start Date
# 65775   1051 Market St         94103.0          02/01/2008
# 135617  1051 Market St         94103.0          12/17/2014
# 214983  1051 Market St         94103.0          09/01/2013

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_id  \
# 0           0             0               0         1757
# 1           1             1               1         4864
#
#                      business_name business_address  business_city  \
# 0  Dar Bar Pakistani/Indian Cusine     1412 Polk St  San Francisco
# 1        DRAGON CITY BAKERY & CAFE  2367 MISSION St  San Francisco
#
#   business_state business_postal_code  business_latitude    ...      \
# 0             CA                94109          37.789784    ...
# 1             CA                94110          37.759174    ...
#
#    inspect_date p1_3  p4_6 p7_9 p10_12  p13_18 p19_24 p25_36 number_turnovers  \
# 0    2017-09-28    0     0    5      0       0      6      5              1.0
# 1    2016-12-06    0     6    0      0       5      5      3              NaN
#
#   start_date
# 0 2003-02-28
# 1        NaT
#
# [2 rows x 32 columns]

# %%
df[df['business_address'] == '1051 Market St']
# Out:
#     Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_id       business_name  \
# 85          85            85             115        81509  The Flying Falafel
#
#    business_address  business_city business_state business_postal_code  \
# 85   1051 Market St  San Francisco             CA                94103
#
#     business_latitude    ...      inspect_date p1_3  p4_6 p7_9 p10_12  p13_18  \
# 85                NaN    ...        2016-12-05    5     0    0      0       4
#
#    p19_24 p25_36 number_turnovers start_date
# 85      0      4              3.0 2014-12-17
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Let's input the average value to missing number_trunovers and start_dates

# %%
df[df['number_turnovers'].isnull()].head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_id  \
# 1           1             1               1         4864
# 3           3             3               3        73840
#
#                business_name    business_address  business_city  \
# 1  DRAGON CITY BAKERY & CAFE     2367 MISSION St  San Francisco
# 3   L'acajou Bakery and Cafe  498 09th St Ste. C  San Francisco
#
#   business_state business_postal_code  business_latitude    ...      \
# 1             CA                94110          37.759174    ...
# 3             CA                94103                NaN    ...
#
#    inspect_date p1_3  p4_6 p7_9 p10_12  p13_18 p19_24 p25_36 number_turnovers  \
# 1    2016-12-06    0     6    0      0       5      5      3              NaN
# 3    2017-12-07    0     5    0      0       6      0      0              NaN
#
#   start_date
# 1        NaT
# 3        NaT
#
# [2 rows x 32 columns]

# %%
mask_turnovers = df['number_turnovers'].isnull()

# %%
# sum(~mask_turnovers) is the number of True in number_turnovers
avg_turnover = sum(df['number_turnovers'][~mask_turnovers])/sum(~mask_turnovers)

# %%
df[df['start_date'].isnull()].head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_id  \
# 1           1             1               1         4864
# 3           3             3               3        73840
#
#                business_name    business_address  business_city  \
# 1  DRAGON CITY BAKERY & CAFE     2367 MISSION St  San Francisco
# 3   L'acajou Bakery and Cafe  498 09th St Ste. C  San Francisco
#
#   business_state business_postal_code  business_latitude    ...      \
# 1             CA                94110          37.759174    ...
# 3             CA                94103                NaN    ...
#
#    inspect_date p1_3  p4_6 p7_9 p10_12  p13_18 p19_24 p25_36 number_turnovers  \
# 1    2016-12-06    0     6    0      0       5      5      3              NaN
# 3    2017-12-07    0     5    0      0       6      0      0              NaN
#
#   start_date
# 1        NaT
# 3        NaT
#
# [2 rows x 32 columns]

# %%
df.loc[mask_turnovers, 'number_turnovers'] = avg_turnover

# %%
df.head(2)
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_id  \
# 0           0             0               0         1757
# 1           1             1               1         4864
#
#                      business_name business_address  business_city  \
# 0  Dar Bar Pakistani/Indian Cusine     1412 Polk St  San Francisco
# 1        DRAGON CITY BAKERY & CAFE  2367 MISSION St  San Francisco
#
#   business_state business_postal_code  business_latitude    ...      \
# 0             CA                94109          37.789784    ...
# 1             CA                94110          37.759174    ...
#
#    inspect_date p1_3  p4_6 p7_9 p10_12  p13_18 p19_24 p25_36 number_turnovers  \
# 0    2017-09-28    0     0    5      0       0      6      5         1.000000
# 1    2016-12-06    0     6    0      0       5      5      3         4.447019
#
#   start_date
# 0 2003-02-28
# 1        NaT
#
# [2 rows x 32 columns]

# %% [markdown]
# ## convert datetime in start_date to integer to use it for modeling

# %%
#df.loc[:,'start_date'] = df.loc[:,'start_date'].dt.strftime('%Y%m%d')

# %%
#df.loc[~mask_turnovers,'start_date'] = df.loc[~mask_turnovers,'start_date'].astype(int)

# %%
#avg_startdate = sum(df['start_date'][~mask_turnovers].values)/sum(~mask_turnovers)

# %%
#df.loc[mask_turnovers, 'start_date'] = int(avg_startdate)

# %%
#df.head(5)

# %% [markdown]
# ## Years in business

# %%
# Find the months in business for each restaurant by subtracting their starting date from End of March 2018.

# %%
df['start_date'].head()
# Out:
# 0   2003-02-28
# 1          NaT
# 2   2011-06-15
# 3          NaT
# 4   2010-04-01
# Name: start_date, dtype: datetime64[ns]

# %%
end_of_march_2018 = latest_startdate = pd.to_datetime('03/31/2018')

# %%
end_of_march_2018
# Out:
# Timestamp('2018-03-31 00:00:00')

# %%
df['duration_business'] = ((end_of_march_2018 - df['start_date'])/ np.timedelta64(1, 'M'))

# %%
((end_of_march_2018 - df['start_date']))
# Out:
# 0       5510 days
# 1             NaT
# 2       2481 days
# 3             NaT
# 4       2921 days
# 5       2190 days
# 6      12478 days
# 7      12448 days
# 8       3379 days
# 9             NaT
# 10      4291 days
# 11      1209 days
# 12      4644 days
# 13            NaT
# 14            NaT
# 15            NaT
# 16      2720 days
# 17            NaT
# 18            NaT
# 19      2094 days
# 20      6512 days
# 21            NaT
# 22      7102 days
# 23      8198 days
# 24     10375 days
# 25      2389 days
# 26            NaT
# 27            NaT
# 28      2403 days
# 29      4784 days
#           ...
# 5199    3463 days
# 5200    4168 days
# 5201     620 days
# 5202    3742 days
# 5203          NaT
# 5204          NaT
# 5205    6390 days
# 5206          NaT
# 5207    3120 days
# 5208          NaT
# 5209          NaT
# 5210          NaT
# 5211          NaT
# 5212    5295 days
# 5213          NaT
# 5214          NaT
# 5215          NaT
# 5216    6358 days
# 5217          NaT
# 5218    5456 days
# 5219          NaT
# 5220          NaT
# 5221          NaT
# 5222     134 days
# 5223     155 days
# 5224          NaT
# 5225     157 days
# 5226    2346 days
# 5227    3286 days
# 5228   10135 days
# Name: start_date, Length: 5229, dtype: timedelta64[ns]

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_id  \
# 0           0             0               0         1757
# 1           1             1               1         4864
# 2           2             2               2        79782
# 3           3             3               3        73840
# 4           4             4               4        76437
#
#                      business_name    business_address  business_city  \
# 0  Dar Bar Pakistani/Indian Cusine        1412 Polk St  San Francisco
# 1        DRAGON CITY BAKERY & CAFE     2367 MISSION St  San Francisco
# 2                          Deli 23        2449 23rd St  San Francisco
# 3         L'acajou Bakery and Cafe  498 09th St Ste. C  San Francisco
# 4                  Sweetheart Cafe       909 Grant Ave  San Francisco
#
#   business_state business_postal_code  business_latitude        ...         \
# 0             CA                94109          37.789784        ...
# 1             CA                94110          37.759174        ...
# 2             CA                94110                NaN        ...
# 3             CA                94103                NaN        ...
# 4             CA                94108                NaN        ...
#
#    p1_3 p4_6  p7_9 p10_12 p13_18  p19_24 p25_36 number_turnovers start_date  \
# 0     0    0     5      0      0       6      5              1.0 2003-02-28
# 1     0    6     0      0      5       5      3              NaN        NaT
# 2     4    0     2      0      3       3      2              3.0 2011-06-15
# 3     0    5     0      0      6       0      0              NaN        NaT
# 4     0   11     0      0      0       6      6              2.0 2010-04-01
#
#   duration_business
# 0        181.030411
# 1               NaN
# 2         81.512967
# 3               NaN
# 4         95.969116
#
# [5 rows x 33 columns]

# %%
avg_duration = sum(df['duration_business'][~mask_turnovers].values)/sum(~mask_turnovers)

# %%
df.loc[mask_turnovers, 'duration_business'] = avg_duration

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  business_id  \
# 0           0             0               0         1757
# 1           1             1               1         4864
# 2           2             2               2        79782
# 3           3             3               3        73840
# 4           4             4               4        76437
#
#                      business_name    business_address  business_city  \
# 0  Dar Bar Pakistani/Indian Cusine        1412 Polk St  San Francisco
# 1        DRAGON CITY BAKERY & CAFE     2367 MISSION St  San Francisco
# 2                          Deli 23        2449 23rd St  San Francisco
# 3         L'acajou Bakery and Cafe  498 09th St Ste. C  San Francisco
# 4                  Sweetheart Cafe       909 Grant Ave  San Francisco
#
#   business_state business_postal_code  business_latitude        ...         \
# 0             CA                94109          37.789784        ...
# 1             CA                94110          37.759174        ...
# 2             CA                94110                NaN        ...
# 3             CA                94103                NaN        ...
# 4             CA                94108                NaN        ...
#
#    p1_3 p4_6  p7_9 p10_12 p13_18  p19_24 p25_36 number_turnovers start_date  \
# 0     0    0     5      0      0       6      5              1.0 2003-02-28
# 1     0    6     0      0      5       5      3              NaN        NaT
# 2     4    0     2      0      3       3      2              3.0 2011-06-15
# 3     0    5     0      0      6       0      0              NaN        NaT
# 4     0   11     0      0      0       6      6              2.0 2010-04-01
#
#   duration_business
# 0        181.030411
# 1        153.101342
# 2         81.512967
# 3        153.101342
# 4         95.969116
#
# [5 rows x 33 columns]
